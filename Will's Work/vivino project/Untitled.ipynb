# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium import webdriver

# %%
options = webdriver.ChromeOptions() 
options.add_argument("start-maximized")
options.add_argument('--disable-blink-features=AutomationControlled')

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, options=options)

# %%
url = 'https://www.totalwine.com/'

# %%
browser.visit(url)

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(browser.html, 'html.parser')
print(soup.prettify())
# Out:
# <html lang="en">
#  <head class="at-element-marker" profile="http://www.w3.org/2005/10/profile">
#   <script src="https://bam.nr-data.net/1/5a2ea98f06?a=736890546&amp;sa=1&amp;v=1169.7b094c0&amp;t=Unnamed%20Transaction&amp;rst=5445&amp;ck=1&amp;ref=https://www.totalwine.com/discover/trends-and-occasions/best-wines&amp;be=2595&amp;fe=5347&amp;af=err,xhr,stn,ins&amp;perf=%7B%22timing%22:%7B%22of%22:1671160350401,%22n%22:0,%22u%22:65,%22ue%22:77,%22f%22:4,%22dn%22:4,%22dne%22:4,%22c%22:4,%22ce%22:4,%22rq%22:6,%22rp%22:40,%22rpe%22:53,%22dl%22:94,%22di%22:2412,%22ds%22:2412,%22de%22:2516,%22dc%22:5342,%22l%22:5342,%22le%22:5355%7D,%22navigation%22:%7B%7D%7D&amp;fp=188&amp;fcp=188&amp;jsonp=NREUM.setToken" type="text/javascript">
#   </script>
#   <script async="" src="//cdn.brcdn.com/v1/br-trk-6293.js" type="text/javascript">
#   </script>
#   <script src="https://js-agent.newrelic.com/nr-1169.min.js">
#   </script>
# ...

# %%
#Your IP address (70.120.200.54) has been temporarily blocked for exceeding bulk request limits. If you believe this was done in error or you have legitimate needs to access our pages and data above and beyond these limits please contact admin@vivino.com with the subject 'Requests Blocked' and we'll try and resolve the issue.

# %%
results = soup.find_all('div', class_="card offer-card")
results

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_='offer-card__name').text
        # Identify and return price of listing
        price = result.find('h4', offer-card__price).text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(link)
    except AttributeError as e:
        print(e)
